# %%
class Node:
    def __init__(self, val):
        self.val = val
        self.next = None
        self.prev = None
# Out:
# Ellipsis

# %%
class DoubleLinkedList:
    def __init__(self):
        self.head = Node(-1)
        self.tail = Node(-1)
        self.head.next = self.tail
        self.tail.next = self.head

    def insertFront(self, value):
        nHead = Node(value)
        nHead.prev = self.head
        nHead.next = self.head.next

        self.head.next.prev = newNode ### WRITE THIS PROPERLY ONCE I AM IN THE BETTER THINKING STATE!
        self.head.next
